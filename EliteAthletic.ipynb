# %%
import pandas as pd
import random

positions = [
    "Point Guard",
    "Shooting Guard",
    "Small Forward",
    "Power Forward",
    "Center"
]

experience_levels = [
    "Beginner",
    "Intermediate",
    "Advanced"
]

goals = [
    "Improve shooting",
    "Increase speed",
    "Improve ball handling",
    "Increase vertical jump",
    "Improve conditioning",
    "Improve defense",
    "Build strength",
    "Improve agility"
]

injuries = [
    "None",
    "Ankle Recovery",
    "Knee Recovery",
    "Minor Shoulder Pain"
]

equipment_options = [
    "Basketball",
    "Basketball, Cones",
    "Basketball, Resistance Bands",
    "Basketball, Gym Access",
    "Basketball, Cones, Gym Access",
    "Basketball, Cones, Resistance Bands, Gym Access"
]

profiles = []

for i in range(1, 31):

    athlete = {
        "athlete_id": f"A{i:03}",
        "age": random.randint(13, 17),
        "sport": "Basketball",
        "position": random.choice(positions),
        "experience_level": random.choice(experience_levels),
        "goal": random.choice(goals),
        "injury_status": random.choice(injuries),
        "available_days": random.randint(2, 6),
        "equipment": random.choice(equipment_options),
        "notes": "Parent/Coach Oversight Required"
    }

    profiles.append(athlete)

df = pd.DataFrame(profiles)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>athlete_id</th><th>age</th><th>sport</th><th>position</th><th>experience_level</th><th>goal</th><th>injury_status</th><th>available_days</th><th>equipment</th><th>notes</th></tr></thead><tbody><tr><td>A001</td><td>17</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Improve agility</td><td>Minor Shoulder Pain</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A002</td><td>14</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Increase speed</td><td>None</td><td>3</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A003</td><td>14</td><td>Basketball</td><td>Shooting Guard</td><td>Beginner</td><td>Improve ball handling</td><td>Knee Recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A004</td><td>14</td><td>Basketball</td><td>Power Forward</td><td>Advanced</td><td>Improve defense</td><td>None</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A005</td><td>16</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Build strength</td><td>Knee Recovery</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A006</td><td>15</td><td>Basketball</td><td>Center</td><td>Beginner</td><td>Increase vertical jump</td><td>Minor Shoulder Pain</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A007</td><td>13</td><td>Basketball</td><td>Point Guard</td><td>Beginner</td><td>Increase vertical jump</td><td>Ankle Recovery</td><td>5</td><td>Basketball, Cones, Resistance Bands, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A008</td><td>16</td><td>Basketball</td><td>Point Guard</td><td>Advanced</td><td>Build strength</td><td>Knee Recovery</td><td>4</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A009</td><td>13</td><td>Basketball</td><td>Small Forward</td><td>Intermediate</td><td>Improve defense</td><td>Minor Shoulder Pain</td><td>5</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A010</td><td>16</td><td>Basketball</td><td>Shooting Guard</td><td>Intermediate</td><td>Improve conditioning</td><td>None</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A011</td><td>17</td><td>Basketball</td><td>Center</td><td>Advanced</td><td>Improve agility</td><td>None</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A012</td><td>13</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Improve ball handling</td><td>Ankle Recovery</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A013</td><td>17</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Improve conditioning</td><td>Ankle Recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A014</td><td>13</td><td>Basketball</td><td>Shooting Guard</td><td>Intermediate</td><td>Increase speed</td><td>None</td><td>6</td><td>Basketball, Cones, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A015</td><td>16</td><td>Basketball</td><td>Point Guard</td><td>Beginner</td><td>Improve defense</td><td>None</td><td>4</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A016</td><td>15</td><td>Basketball</td><td>Point Guard</td><td>Beginner</td><td>Increase vertical jump</td><td>None</td><td>6</td><td>Basketball, Cones</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A017</td><td>13</td><td>Basketball</td><td>Center</td><td>Beginner</td><td>Increase speed</td><td>None</td><td>2</td><td>Basketball, Cones, Gym Access</td><td>Parent/Coach Oversight Required< ...

# %%
csv_path = "/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/athlete_test_profiles.csv"

df.to_csv(csv_path, index=False)

print(f"Saved to: {csv_path}")
# Out:
# Saved to: /Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/athlete_test_profiles.csv

# %%
import os

os.path.exists("/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/athlete_test_profiles.csv")
# Out:
# True

# %%
# --Load Back Into Spark -- 
athlete_df = spark.read.csv(
    "/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/athlete_test_profiles.csv",
    header=True,
    inferSchema=True
)

display(athlete_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>athlete_id</th><th>age</th><th>sport</th><th>position</th><th>experience_level</th><th>goal</th><th>injury_status</th><th>available_days</th><th>equipment</th><th>notes</th></tr></thead><tbody><tr><td>A001</td><td>17</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Improve agility</td><td>Minor Shoulder Pain</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A002</td><td>14</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Increase speed</td><td>None</td><td>3</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A003</td><td>14</td><td>Basketball</td><td>Shooting Guard</td><td>Beginner</td><td>Improve ball handling</td><td>Knee Recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A004</td><td>14</td><td>Basketball</td><td>Power Forward</td><td>Advanced</td><td>Improve defense</td><td>None</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A005</td><td>16</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Build strength</td><td>Knee Recovery</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A006</td><td>15</td><td>Basketball</td><td>Center</td><td>Beginner</td><td>Increase vertical jump</td><td>Minor Shoulder Pain</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A007</td><td>13</td><td>Basketball</td><td>Point Guard</td><td>Beginner</td><td>Increase vertical jump</td><td>Ankle Recovery</td><td>5</td><td>Basketball, Cones, Resistance Bands, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A008</td><td>16</td><td>Basketball</td><td>Point Guard</td><td>Advanced</td><td>Build strength</td><td>Knee Recovery</td><td>4</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A009</td><td>13</td><td>Basketball</td><td>Small Forward</td><td>Intermediate</td><td>Improve defense</td><td>Minor Shoulder Pain</td><td>5</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A010</td><td>16</td><td>Basketball</td><td>Shooting Guard</td><td>Intermediate</td><td>Improve conditioning</td><td>None</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A011</td><td>17</td><td>Basketball</td><td>Center</td><td>Advanced</td><td>Improve agility</td><td>None</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A012</td><td>13</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Improve ball handling</td><td>Ankle Recovery</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A013</td><td>17</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Improve conditioning</td><td>Ankle Recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A014</td><td>13</td><td>Basketball</td><td>Shooting Guard</td><td>Intermediate</td><td>Increase speed</td><td>None</td><td>6</td><td>Basketball, Cones, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A015</td><td>16</td><td>Basketball</td><td>Point Guard</td><td>Beginner</td><td>Improve defense</td><td>None</td><td>4</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A016</td><td>15</td><td>Basketball</td><td>Point Guard</td><td>Beginner</td><td>Increase vertical jump</td><td>None</td><td>6</td><td>Basketball, Cones</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A017</td><td>13</td><td>Basketball</td><td>Center</td><td>Beginner</td><td>Increase speed</td><td>None</td><td>2</td><td>Basketball, Cones, Gym Access</td><td>Parent/Coach Oversight Required< ...

# %%
# Save as a Bronze Table -- This is what we'll use later for your agent

athlete_df.write.mode("overwrite").saveAsTable(
    "main.default.bronze_athlete_profiles"
)

# %%
# %sql
SELECT *
FROM main.default.bronze_athlete_profiles
LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>athlete_id</th><th>age</th><th>sport</th><th>position</th><th>experience_level</th><th>goal</th><th>injury_status</th><th>available_days</th><th>equipment</th><th>notes</th></tr></thead><tbody><tr><td>A001</td><td>17</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Improve agility</td><td>Minor Shoulder Pain</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A002</td><td>14</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Increase speed</td><td>None</td><td>3</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A003</td><td>14</td><td>Basketball</td><td>Shooting Guard</td><td>Beginner</td><td>Improve ball handling</td><td>Knee Recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A004</td><td>14</td><td>Basketball</td><td>Power Forward</td><td>Advanced</td><td>Improve defense</td><td>None</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A005</td><td>16</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Build strength</td><td>Knee Recovery</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A006</td><td>15</td><td>Basketball</td><td>Center</td><td>Beginner</td><td>Increase vertical jump</td><td>Minor Shoulder Pain</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A007</td><td>13</td><td>Basketball</td><td>Point Guard</td><td>Beginner</td><td>Increase vertical jump</td><td>Ankle Recovery</td><td>5</td><td>Basketball, Cones, Resistance Bands, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A008</td><td>16</td><td>Basketball</td><td>Point Guard</td><td>Advanced</td><td>Build strength</td><td>Knee Recovery</td><td>4</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A009</td><td>13</td><td>Basketball</td><td>Small Forward</td><td>Intermediate</td><td>Improve defense</td><td>Minor Shoulder Pain</td><td>5</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A010</td><td>16</td><td>Basketball</td><td>Shooting Guard</td><td>Intermediate</td><td>Improve conditioning</td><td>None</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr></tbody></table></div>

# %%
#Setting the Catalog/Schema 

spark.sql("USE CATALOG main")
spark.sql("USE SCHEMA default")
# Out:
# DataFrame[]

# %%
#Defining the file path 
base_path = "dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project"

files = {
    "bronze_athlete_profiles": "athlete_test_profiles.csv",
    "bronze_player_data": "player_data.csv",
    "bronze_players": "Players.csv",
    "bronze_nba_stats": "Seasons_Stats.csv",
    "bronze_gym_exercises": "megaGymDataset.csv",
    "bronze_food_sample": "sub_sample_food.csv",
    "bronze_food_nutrients": "sub_sample_result.csv",
    "bronze_food_categories": "food_category.csv",
    "bronze_food_portions": "food_portion.csv"
}

# %%
display(dbutils.fs.ls("dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/New Notebook 2026-06-07 11:03:39.ipynb</td><td>New Notebook 2026-06-07 11:03:39.ipynb</td><td>9316</td><td>1780846846032</td></tr><tr><td>dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/Players.csv</td><td>Players.csv</td><td>281111</td><td>1780846709903</td></tr><tr><td>dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/Seasons_Stats.csv</td><td>Seasons_Stats.csv</td><td>5117407</td><td>1780846710830</td></tr><tr><td>dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/athlete_test_profiles.csv</td><td>athlete_test_profiles.csv</td><td>4141</td><td>1780845443678</td></tr><tr><td>dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/food_category.csv</td><td>food_category.csv</td><td>997</td><td>1780846824055</td></tr><tr><td>dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/food_portion.csv</td><td>food_portion.csv</td><td>714051</td><td>1780846824295</td></tr><tr><td>dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/megaGymDataset.csv</td><td>megaGymDataset.csv</td><td>673158</td><td>1780846732671</td></tr><tr><td>dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/player_data.csv</td><td>player_data.csv</td><td>346695</td><td>1780846709847</td></tr><tr><td>dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/sub_sample_food.csv</td><td>sub_sample_food.csv</td><td>1478511</td><td>1780846786177</td></tr><tr><td>dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/sub_sample_result.csv</td><td>sub_sample_result.csv</td><td>5294585</td><td>1780846786989</td></tr></tbody></table></div>

# %%
base_path = (
    "dbfs:/Workspace/Users/bzekaryas@sandiego.edu/"
    "Elite Athletic - Final Project/"
)

# %%
#Quick test -- 
nba_df = spark.read.csv(
    base_path + "Seasons_Stats.csv",
    header=True,
    inferSchema=True
)

display(nba_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Year</th><th>Player</th><th>Pos</th><th>Age</th><th>Tm</th><th>G</th><th>GS</th><th>MP</th><th>PER</th><th>TS%</th><th>3PAr</th><th>FTr</th><th>ORB%</th><th>DRB%</th><th>TRB%</th><th>AST%</th><th>STL%</th><th>BLK%</th><th>TOV%</th><th>USG%</th><th>blanl</th><th>OWS</th><th>DWS</th><th>WS</th><th>WS/48</th><th>blank2</th><th>OBPM</th><th>DBPM</th><th>BPM</th><th>VORP</th><th>FG</th><th>FGA</th><th>FG%</th><th>3P</th><th>3PA</th><th>3P%</th><th>2P</th><th>2PA</th><th>2P%</th><th>eFG%</th><th>FT</th><th>FTA</th><th>FT%</th><th>ORB</th><th>DRB</th><th>TRB</th><th>AST</th><th>STL</th><th>BLK</th><th>TOV</th><th>PF</th><th>PTS</th></tr></thead><tbody><tr><td>0</td><td>1950</td><td>Curly Armstrong</td><td>G-F</td><td>31</td><td>FTW</td><td>63</td><td>null</td><td>null</td><td>null</td><td>0.368</td><td>null</td><td>0.467</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>-0.1</td><td>3.6</td><td>3.5</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>144</td><td>516</td><td>0.279</td><td>null</td><td>null</td><td>null</td><td>144</td><td>516</td><td>0.279</td><td>0.279</td><td>170</td><td>241</td><td>0.705</td><td>null</td><td>null</td><td>null</td><td>176</td><td>null</td><td>null</td><td>null</td><td>217</td><td>458</td></tr><tr><td>1</td><td>1950</td><td>Cliff Barker</td><td>SG</td><td>29</td><td>INO</td><td>49</td><td>null</td><td>null</td><td>null</td><td>0.435</td><td>null</td><td>0.387</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1.6</td><td>0.6</td><td>2.2</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>102</td><td>274</td><td>0.372</td><td>null</td><td>null</td><td>null</td><td>102</td><td>274</td><td>0.372</td><td>0.372</td><td>75</td><td>106</td><td>0.708</td><td>null</td><td>null</td><td>null</td><td>109</td><td>null</td><td>null</td><td>null</td><td>99</td><td>279</td></tr><tr><td>2</td><td>1950</td><td>Leo Barnhorst</td><td>SF</td><td>25</td><td>CHS</td><td>67</td><td>null</td><td>null</td><td>null</td><td>0.394</td><td>null</td><td>0.259</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.9</td><td>2.8</td><td>3.6</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>174</td><td>499</td><td>0.349</td><td>null</td><td>null</td><td>null</td><td>174</td><td>499</td><td>0.349</td><td>0.349</td><td>90</td><td>129</td><td>0.698</td><td>null</td><td>null</td><td>null</td><td>140</td><td>null</td><td>null</td><td>null</td><td>192</td><td>438</td></tr><tr><td>3</td><td>1950</td><td>Ed Bartels</td><td>F</td><td>24</td><td>TOT</td><td>15</td><td>null</td><td>null</td><td>null</td><td>0.312</td><td>null</td><td>0.395</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>-0.5</td><td>-0.1</td><td>-0.6</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>22</td><td>86</td><td>0.256</td><td>null</td><td>null</td><td>null</td><td>22</td><td>86</td><td>0.256</td><td>0.256</td><td>19</td><td>34</td><td>0.559</td><td>null</td><td>null</td><td>null</td><td>20</td><td>null</td><td>null</td><td>null</td><td>29</td><td>63</td></tr><tr><td>4</td><td>1950</td><td>Ed Bartels</td><td>F</td><td>24</td><td>DNN</td><td>13</td><td>null</td><td>null</td><td>null</td><td>0.308</td><td>null</td><td>0.378</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>-0.5</td><td>-0.1</td><td>-0.6</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>21</td><td>82</td><td>0.256</td><td>null</td><td>null< ...

# %%
Athlete profiles complete -- Bronze data layer inprogress -- Bronze athlet profiles complete

# %%
#Moving to Data Profile & Data Cleaning -- Before building the silver layer
#Generic Data Profiler -- 

from pyspark.sql.functions import col, count, when

def profile_table(table_name):

    print("=" * 80)
    print(f"TABLE: {table_name}")
    print("=" * 80)

    df = spark.table(table_name)

    print(f"\nRows: {df.count()}")
    print(f"Columns: {len(df.columns)}")

    print("\nSchema:")
    df.printSchema()

    print("\nNull Counts:")

    null_counts = df.select([
        count(when(col(c).isNull(), c)).alias(c)
        for c in df.columns
    ])

    display(null_counts)

    print("\nDuplicate Count:")

    duplicates = (
        df.count()
        - df.dropDuplicates().count()
    )

    print(f"Duplicates: {duplicates}")

    print("\nSample Records:")

    display(df.limit(5))

# %%
profile_table(
    "main.default.bronze_athlete_profiles"
)
# Out:
# ================================================================================
# TABLE: main.default.bronze_athlete_profiles
# ================================================================================
#
# Rows: 30
# Columns: 10
#
# Schema:
# root
#  |-- athlete_id: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- sport: string (nullable = true)
#  |-- position: string (nullable = true)
#  |-- experience_level: string (nullable = true)
#  |-- goal: string (nullable = true)
#  |-- injury_status: string (nullable = true)
#  |-- available_days: integer (nullable = true)
#  |-- equipment: string (nullable = true)
#  |-- notes: string (nullable = true)
#
#
# Null Counts:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>athlete_id</th><th>age</th><th>sport</th><th>position</th><th>experience_level</th><th>goal</th><th>injury_status</th><th>available_days</th><th>equipment</th><th>notes</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>
# Duplicate Count:
# Duplicates: 0
#
# Sample Records:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>athlete_id</th><th>age</th><th>sport</th><th>position</th><th>experience_level</th><th>goal</th><th>injury_status</th><th>available_days</th><th>equipment</th><th>notes</th></tr></thead><tbody><tr><td>A001</td><td>17</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Improve agility</td><td>Minor Shoulder Pain</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A002</td><td>14</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Increase speed</td><td>None</td><td>3</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A003</td><td>14</td><td>Basketball</td><td>Shooting Guard</td><td>Beginner</td><td>Improve ball handling</td><td>Knee Recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A004</td><td>14</td><td>Basketball</td><td>Power Forward</td><td>Advanced</td><td>Improve defense</td><td>None</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A005</td><td>16</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Build strength</td><td>Knee Recovery</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr></tbody></table></div>

# %%
spark.sql("SHOW TABLES IN main.default").show(truncate=False)
# Out:
# +--------+-------------------------+-----------+
# |database|tableName                |isTemporary|
# +--------+-------------------------+-----------+
# |default |assignment_file          |false      |
# |default |bronze_athlete_profiles  |false      |
# |default |ultrafeedback_embeddings |false      |
# |default |ultrafeedback_expert_eval|false      |
# +--------+-------------------------+-----------+

# %%
athlete_df = spark.table("main.default.bronze_athlete_profiles")
display(athlete_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>athlete_id</th><th>age</th><th>sport</th><th>position</th><th>experience_level</th><th>goal</th><th>injury_status</th><th>available_days</th><th>equipment</th><th>notes</th></tr></thead><tbody><tr><td>A001</td><td>17</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Improve agility</td><td>Minor Shoulder Pain</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A002</td><td>14</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Increase speed</td><td>None</td><td>3</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A003</td><td>14</td><td>Basketball</td><td>Shooting Guard</td><td>Beginner</td><td>Improve ball handling</td><td>Knee Recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A004</td><td>14</td><td>Basketball</td><td>Power Forward</td><td>Advanced</td><td>Improve defense</td><td>None</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A005</td><td>16</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Build strength</td><td>Knee Recovery</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A006</td><td>15</td><td>Basketball</td><td>Center</td><td>Beginner</td><td>Increase vertical jump</td><td>Minor Shoulder Pain</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A007</td><td>13</td><td>Basketball</td><td>Point Guard</td><td>Beginner</td><td>Increase vertical jump</td><td>Ankle Recovery</td><td>5</td><td>Basketball, Cones, Resistance Bands, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A008</td><td>16</td><td>Basketball</td><td>Point Guard</td><td>Advanced</td><td>Build strength</td><td>Knee Recovery</td><td>4</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A009</td><td>13</td><td>Basketball</td><td>Small Forward</td><td>Intermediate</td><td>Improve defense</td><td>Minor Shoulder Pain</td><td>5</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A010</td><td>16</td><td>Basketball</td><td>Shooting Guard</td><td>Intermediate</td><td>Improve conditioning</td><td>None</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A011</td><td>17</td><td>Basketball</td><td>Center</td><td>Advanced</td><td>Improve agility</td><td>None</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A012</td><td>13</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Improve ball handling</td><td>Ankle Recovery</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A013</td><td>17</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Improve conditioning</td><td>Ankle Recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A014</td><td>13</td><td>Basketball</td><td>Shooting Guard</td><td>Intermediate</td><td>Increase speed</td><td>None</td><td>6</td><td>Basketball, Cones, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A015</td><td>16</td><td>Basketball</td><td>Point Guard</td><td>Beginner</td><td>Improve defense</td><td>None</td><td>4</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A016</td><td>15</td><td>Basketball</td><td>Point Guard</td><td>Beginner</td><td>Increase vertical jump</td><td>None</td><td>6</td><td>Basketball, Cones</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A017</td><td>13</td><td>Basketball</td><td>Center</td><td>Beginner</td><td>Increase speed</td><td>None</td><td>2</td><td>Basketball, Cones, Gym Access</td><td>Parent/Coach Oversight Required< ...

# %%
base_path = "dbfs:/Workspace/Users/bzekaryas@sandiego.edu/Elite Athletic - Final Project/"

files = {
    "bronze_nba_stats": "Seasons_Stats.csv",
    "bronze_player_data": "player_data.csv",
    "bronze_players": "Players.csv",
    "bronze_gym_exercises": "megaGymDataset.csv",
    "bronze_food_sample": "sub_sample_food.csv",
    "bronze_food_nutrients": "sub_sample_result.csv",
    "bronze_food_categories": "food_category.csv",
    "bronze_food_portions": "food_portion.csv"
}

for table_name, file_name in files.items():
    path = base_path + file_name

    df = (
        spark.read
        .option("header", True)
        .option("inferSchema", True)
        .csv(path)
    )

    df.write.mode("overwrite").saveAsTable(f"main.default.{table_name}")

    print(f"Created: main.default.{table_name}")
# Out:
# Created: main.default.bronze_nba_stats
# Created: main.default.bronze_player_data
# Created: main.default.bronze_players
# Created: main.default.bronze_gym_exercises
# Created: main.default.bronze_food_sample
# Created: main.default.bronze_food_nutrients
# Created: main.default.bronze_food_categories
# Created: main.default.bronze_food_portions

# %%
#This should show the Bronze layer is now complete 
spark.sql("SHOW TABLES IN main.default").show(truncate=False)
# Out:
# +--------+-------------------------+-----------+
# |database|tableName                |isTemporary|
# +--------+-------------------------+-----------+
# |default |assignment_file          |false      |
# |default |bronze_athlete_profiles  |false      |
# |default |bronze_food_categories   |false      |
# |default |bronze_food_nutrients    |false      |
# |default |bronze_food_portions     |false      |
# |default |bronze_food_sample       |false      |
# |default |bronze_gym_exercises     |false      |
# |default |bronze_nba_stats         |false      |
# |default |bronze_player_data       |false      |
# |default |bronze_players           |false      |
# |default |ultrafeedback_embeddings |false      |
# |default |ultrafeedback_expert_eval|false      |
# +--------+-------------------------+-----------+

# %%
# Running the profiler -- 
tables_to_profile = [
    "main.default.bronze_athlete_profiles",
    "main.default.bronze_nba_stats",
    "main.default.bronze_gym_exercises",
    "main.default.bronze_food_nutrients",
    "main.default.bronze_food_portions"
]

for table in tables_to_profile:
    profile_table(table)
# Out:
# ================================================================================
# TABLE: main.default.bronze_athlete_profiles
# ================================================================================
#
# Rows: 30
# Columns: 10
#
# Schema:
# root
#  |-- athlete_id: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- sport: string (nullable = true)
#  |-- position: string (nullable = true)
#  |-- experience_level: string (nullable = true)
#  |-- goal: string (nullable = true)
#  |-- injury_status: string (nullable = true)
#  |-- available_days: integer (nullable = true)
#  |-- equipment: string (nullable = true)
#  |-- notes: string (nullable = true)
#
#
# Null Counts:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>athlete_id</th><th>age</th><th>sport</th><th>position</th><th>experience_level</th><th>goal</th><th>injury_status</th><th>available_days</th><th>equipment</th><th>notes</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>
# Duplicate Count:
# Duplicates: 0
#
# Sample Records:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>athlete_id</th><th>age</th><th>sport</th><th>position</th><th>experience_level</th><th>goal</th><th>injury_status</th><th>available_days</th><th>equipment</th><th>notes</th></tr></thead><tbody><tr><td>A001</td><td>17</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Improve agility</td><td>Minor Shoulder Pain</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A002</td><td>14</td><td>Basketball</td><td>Small Forward</td><td>Beginner</td><td>Increase speed</td><td>None</td><td>3</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A003</td><td>14</td><td>Basketball</td><td>Shooting Guard</td><td>Beginner</td><td>Improve ball handling</td><td>Knee Recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A004</td><td>14</td><td>Basketball</td><td>Power Forward</td><td>Advanced</td><td>Improve defense</td><td>None</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A005</td><td>16</td><td>Basketball</td><td>Shooting Guard</td><td>Advanced</td><td>Build strength</td><td>Knee Recovery</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr></tbody></table></div>
# ================================================================================
# TABLE: main.default.bronze_nba_stats
# ================================================================================
#
# Rows: 24691
# Columns: 53
#
# Schema:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Player: string (nullable = true)
#  |-- Pos: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Tm: string (nullable = true)
#  |-- G: integer (nullable = true)
#  |-- GS: integer (nullable = true)
#  |-- MP: integer (nullable = true)
#  |-- PER: double (nullable = true)
#  |-- TS%: double (nullable = true)
#  |-- 3PAr: double (nullable = true)
#  |-- FTr: double (nullable = true)
#  |-- ORB%: double (nullable = true)
#  |-- DRB%: double (nullable = true)
#  |-- TRB%: double (nullable = true)
#  |-- AST%: double (nullable = true)
#  |-- STL%: double (nullable = true)
#  |-- BLK%: double (nullable = true)
#  |-- TOV%: double (nullable = true)
#  |-- USG%: double (nullable = true)
#  |-- blanl: string (nullable = true)
#  |-- OWS: double (nullable = true)
#  |-- DWS: double (nullable = true)
#  |-- WS: double (nullable = true)
#  |-- WS/48: double (nullable = true)
#  |-- blank2: string (nullable = true)
#  |-- OBPM: double (nullable = true)
#  |-- DBPM: double (nullable = true)
#  |-- BPM: double (nullable = true)
#  |-- VORP: double (nullable = true)
#  |-- FG: integer (nullable = true)
#  |-- FGA: integer (nullable = true)
#  |-- FG%: double (nullable = true)
#  |-- 3P: integer (nullable = true)
#  |-- 3PA: integer (nullable = true)
#  |-- 3P%: double (nullable = true)
#  |-- 2P: integer (nullable = true)
#  |-- 2PA: integer (nullable = true)
#  |-- 2P%: double (nullable = true)
#  |-- eFG%: double (nullable = true)
#  |-- FT: integer (nullable = true)
#  |-- FTA: integer (nullable = true)
#  |-- FT%: double (nullable = true)
#  |-- ORB: integer (nullable = true)
#  |-- DRB: integer (nullable = true)
#  |-- TRB: integer (nullable = true)
#  |-- AST: integer (nullable = true)
#  |-- STL: integer (nullable = true)
#  |-- BLK: integer (nullable = true)
#  |-- TOV: integer (nullable = true)
#  |-- PF: integer (nullable = true)
#  |-- PTS: integer (nullable = true)
#
#
# Null Counts:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Year</th><th>Player</th><th>Pos</th><th>Age</th><th>Tm</th><th>G</th><th>GS</th><th>MP</th><th>PER</th><th>TS%</th><th>3PAr</th><th>FTr</th><th>ORB%</th><th>DRB%</th><th>TRB%</th><th>AST%</th><th>STL%</th><th>BLK%</th><th>TOV%</th><th>USG%</th><th>blanl</th><th>OWS</th><th>DWS</th><th>WS</th><th>WS/48</th><th>blank2</th><th>OBPM</th><th>DBPM</th><th>BPM</th><th>VORP</th><th>FG</th><th>FGA</th><th>FG%</th><th>3P</th><th>3PA</th><th>3P%</th><th>2P</th><th>2PA</th><th>2P%</th><th>eFG%</th><th>FT</th><th>FTA</th><th>FT%</th><th>ORB</th><th>DRB</th><th>TRB</th><th>AST</th><th>STL</th><th>BLK</th><th>TOV</th><th>PF</th><th>PTS</th></tr></thead><tbody><tr><td>0</td><td>67</td><td>67</td><td>67</td><td>75</td><td>67</td><td>67</td><td>6458</td><td>553</td><td>590</td><td>153</td><td>5852</td><td>166</td><td>3899</td><td>3899</td><td>3120</td><td>2136</td><td>3899</td><td>3899</td><td>5109</td><td>5051</td><td>24691</td><td>106</td><td>106</td><td>106</td><td>590</td><td>24691</td><td>3894</td><td>3894</td><td>3894</td><td>3894</td><td>67</td><td>67</td><td>166</td><td>5764</td><td>5764</td><td>9275</td><td>67</td><td>67</td><td>195</td><td>166</td><td>67</td><td>67</td><td>925</td><td>3894</td><td>3894</td><td>379</td><td>67</td><td>3894</td><td>3894</td><td>5046</td><td>67</td><td>67</td></tr></tbody></table></div>
# Duplicate Count:
# Duplicates: 0
#
# Sample Records:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Year</th><th>Player</th><th>Pos</th><th>Age</th><th>Tm</th><th>G</th><th>GS</th><th>MP</th><th>PER</th><th>TS%</th><th>3PAr</th><th>FTr</th><th>ORB%</th><th>DRB%</th><th>TRB%</th><th>AST%</th><th>STL%</th><th>BLK%</th><th>TOV%</th><th>USG%</th><th>blanl</th><th>OWS</th><th>DWS</th><th>WS</th><th>WS/48</th><th>blank2</th><th>OBPM</th><th>DBPM</th><th>BPM</th><th>VORP</th><th>FG</th><th>FGA</th><th>FG%</th><th>3P</th><th>3PA</th><th>3P%</th><th>2P</th><th>2PA</th><th>2P%</th><th>eFG%</th><th>FT</th><th>FTA</th><th>FT%</th><th>ORB</th><th>DRB</th><th>TRB</th><th>AST</th><th>STL</th><th>BLK</th><th>TOV</th><th>PF</th><th>PTS</th></tr></thead><tbody><tr><td>0</td><td>1950</td><td>Curly Armstrong</td><td>G-F</td><td>31</td><td>FTW</td><td>63</td><td>null</td><td>null</td><td>null</td><td>0.368</td><td>null</td><td>0.467</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>-0.1</td><td>3.6</td><td>3.5</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>144</td><td>516</td><td>0.279</td><td>null</td><td>null</td><td>null</td><td>144</td><td>516</td><td>0.279</td><td>0.279</td><td>170</td><td>241</td><td>0.705</td><td>null</td><td>null</td><td>null</td><td>176</td><td>null</td><td>null</td><td>null</td><td>217</td><td>458</td></tr><tr><td>1</td><td>1950</td><td>Cliff Barker</td><td>SG</td><td>29</td><td>INO</td><td>49</td><td>null</td><td>null</td><td>null</td><td>0.435</td><td>null</td><td>0.387</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1.6</td><td>0.6</td><td>2.2</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>102</td><td>274</td><td>0.372</td><td>null</td><td>null</td><td>null</td><td>102</td><td>274</td><td>0.372</td><td>0.372</td><td>75</td><td>106</td><td>0.708</td><td>null</td><td>null</td><td>null</td><td>109</td><td>null</td><td>null</td><td>null</td><td>99</td><td>279</td></tr><tr><td>2</td><td>1950</td><td>Leo Barnhorst</td><td>SF</td><td>25</td><td>CHS</td><td>67</td><td>null</td><td>null</td><td>null</td><td>0.394</td><td>null</td><td>0.259</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.9</td><td>2.8</td><td>3.6</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>174</td><td>499</td><td>0.349</td><td>null</td><td>null</td><td>null</td><td>174</td><td>499</td><td>0.349</td><td>0.349</td><td>90</td><td>129</td><td>0.698</td><td>null</td><td>null</td><td>null</td><td>140</td><td>null</td><td>null</td><td>null</td><td>192</td><td>438</td></tr><tr><td>3</td><td>1950</td><td>Ed Bartels</td><td>F</td><td>24</td><td>TOT</td><td>15</td><td>null</td><td>null</td><td>null</td><td>0.312</td><td>null</td><td>0.395</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>-0.5</td><td>-0.1</td><td>-0.6</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>22</td><td>86</td><td>0.256</td><td>null</td><td>null</td><td>null</td><td>22</td><td>86</td><td>0.256</td><td>0.256</td><td>19</td><td>34</td><td>0.559</td><td>null</td><td>null</td><td>null</td><td>20</td><td>null</td><td>null</td><td>null</td><td>29</td><td>63</td></tr><tr><td>4</td><td>1950</td><td>Ed Bartels</td><td>F</td><td>24</td><td>DNN</td><td>13</td><td>null</td><td>null</td><td>null</td><td>0.308</td><td>null</td><td>0.378</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>-0.5</td><td>-0.1</td><td>-0.6</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>21</td><td>82</td><td>0.256</td><td>null</td><td>null< ...
# ================================================================================
# TABLE: main.default.bronze_gym_exercises
# ================================================================================
#
# Rows: 2918
# Columns: 9
#
# Schema:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- Desc: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- BodyPart: string (nullable = true)
#  |-- Equipment: string (nullable = true)
#  |-- Level: string (nullable = true)
#  |-- Rating: string (nullable = true)
#  |-- RatingDesc: string (nullable = true)
#
#
# Null Counts:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Title</th><th>Desc</th><th>Type</th><th>BodyPart</th><th>Equipment</th><th>Level</th><th>Rating</th><th>RatingDesc</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>1550</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1840</td><td>2028</td></tr></tbody></table></div>
# Duplicate Count:
# Duplicates: 0
#
# Sample Records:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Title</th><th>Desc</th><th>Type</th><th>BodyPart</th><th>Equipment</th><th>Level</th><th>Rating</th><th>RatingDesc</th></tr></thead><tbody><tr><td>0</td><td>Partner plank band row</td><td>The partner plank band row is an abdominal exercise where two partners perform single-arm planks while pulling on the opposite ends of an exercise band. This technique can be done for time or reps in any ab-focused workout.</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>Intermediate</td><td>0.0</td><td>null</td></tr><tr><td>1</td><td>Banded crunch isometric hold</td><td>"The banded crunch isometric hold is an exercise targeting the abdominal muscles, particularly the rectus abdominis or ""six-pack"" muscles. The band adds resistance and continuous tension to this popular exercise."</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>Intermediate</td><td>null</td><td>null</td></tr><tr><td>2</td><td>FYR Banded Plank Jack</td><td>The banded plank jack is a variation on the plank that involves moving the legs in and out for repetitions. Having a band around the thighs forces the lower body to work harder, particularly the hips and glutes. The plank jack is commonly performed as part of a bodyweight circuit, or as part of a dynamic warm-up.</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>Intermediate</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Banded crunch</td><td>"The banded crunch is an exercise targeting the abdominal muscles, particularly the rectus abdominis or ""six-pack"" muscles. The band adds resistance and continuous tension to this popular exercise."</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>Intermediate</td><td>null</td><td>null</td></tr><tr><td>4</td><td>Crunch</td><td>"The crunch is a popular core exercise targeting the rectus abdominis, or ""six-pack"" muscles</td><td> as well as the obliques. It has been the centerpiece of many ab-focused workouts</td><td> due to both its simplicity and the intense burn and mind-muscle connection it produces. It can be performed for time or reps as part of the ab-focused portion of any workout."</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>Intermediate</td></tr></tbody></table></div>
# ================================================================================
# TABLE: main.default.bronze_food_nutrients
# ================================================================================
#
# Rows: 134267
# Columns: 4
#
# Schema:
# root
#  |-- food_nutrient_id: integer (nullable = true)
#  |-- adjusted_amount: double (nullable = true)
#  |-- lab_method_id: integer (nullable = true)
#  |-- nutrient_name: string (nullable = true)
#
#
# Null Counts:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>food_nutrient_id</th><th>adjusted_amount</th><th>lab_method_id</th><th>nutrient_name</th></tr></thead><tbody><tr><td>0</td><td>34072</td><td>0</td><td>0</td></tr></tbody></table></div>
# Duplicate Count:
# Duplicates: 0
#
# Sample Records:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>food_nutrient_id</th><th>adjusted_amount</th><th>lab_method_id</th><th>nutrient_name</th></tr></thead><tbody><tr><td>2201844</td><td>1.98</td><td>1004</td><td>Ash</td></tr><tr><td>2201845</td><td>1.28</td><td>1001</td><td>Nitrogen by Dumas</td></tr><tr><td>2201846</td><td>19.0</td><td>1053</td><td>Fat</td></tr><tr><td>2201847</td><td>56.3</td><td>1007</td><td>Moisture</td></tr><tr><td>2201848</td><td>46.2</td><td>1009</td><td>Calcium</td></tr></tbody></table></div>
# ================================================================================
# TABLE: main.default.bronze_food_portions
# ================================================================================
#
# Rows: 10951
# Columns: 11
#
# Schema:
# root
#  |-- id: integer (nullable = true)
#  |-- fdc_id: integer (nullable = true)
#  |-- seq_num: integer (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- measure_unit_id: integer (nullable = true)
#  |-- portion_description: string (nullable = true)
#  |-- modifier: string (nullable = true)
#  |-- gram_weight: double (nullable = true)
#  |-- data_points: integer (nullable = true)
#  |-- footnote: string (nullable = true)
#  |-- min_year_acquired: integer (nullable = true)
#
#
# Null Counts:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>fdc_id</th><th>seq_num</th><th>amount</th><th>measure_unit_id</th><th>portion_description</th><th>modifier</th><th>gram_weight</th><th>data_points</th><th>footnote</th><th>min_year_acquired</th></tr></thead><tbody><tr><td>0</td><td>273</td><td>10455</td><td>0</td><td>273</td><td>10950</td><td>2237</td><td>0</td><td>69</td><td>10951</td><td>10764</td></tr></tbody></table></div>
# Duplicate Count:
# Duplicates: 0
#
# Sample Records:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>fdc_id</th><th>seq_num</th><th>amount</th><th>measure_unit_id</th><th>portion_description</th><th>modifier</th><th>gram_weight</th><th>data_points</th><th>footnote</th><th>min_year_acquired</th></tr></thead><tbody><tr><td>118702</td><td>319875</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>35.8</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118703</td><td>319880</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>36.2</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118704</td><td>319881</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>33.4</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118705</td><td>319886</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>33.2</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118706</td><td>319889</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>34.6</td><td>1</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
#Raw count summary -- 
for table in tables_to_profile:
    df = spark.table(table)
    print(f"{table}: {df.count()} rows, {len(df.columns)} columns")
# Out:
# main.default.bronze_athlete_profiles: 30 rows, 10 columns
# main.default.bronze_nba_stats: 24691 rows, 53 columns
# main.default.bronze_gym_exercises: 2918 rows, 9 columns
# main.default.bronze_food_nutrients: 134267 rows, 4 columns
# main.default.bronze_food_portions: 10951 rows, 11 columns

# %%
#setting Catalog/Schema -- 
spark.sql("USE CATALOG main")
spark.sql("USE SCHEMA default")
# Out:
# DataFrame[]

# %%
#Silvering Athlete Profiles
from pyspark.sql.functions import col, trim, lower

athlete = spark.table("main.default.bronze_athlete_profiles")

silver_athlete = (
    athlete
    .dropDuplicates(["athlete_id"])
    .withColumn("sport", lower(trim(col("sport"))))
    .withColumn("position", trim(col("position")))
    .withColumn("experience_level", lower(trim(col("experience_level"))))
    .withColumn("injury_status", lower(trim(col("injury_status"))))
    .withColumn("available_days", col("available_days").cast("int"))
    .filter((col("age") >= 13) & (col("age") <= 17))
)

silver_athlete.write.mode("overwrite").saveAsTable(
    "main.default.silver_athlete_profiles"
)

display(silver_athlete)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>athlete_id</th><th>age</th><th>sport</th><th>position</th><th>experience_level</th><th>goal</th><th>injury_status</th><th>available_days</th><th>equipment</th><th>notes</th></tr></thead><tbody><tr><td>A001</td><td>17</td><td>basketball</td><td>Shooting Guard</td><td>advanced</td><td>Improve agility</td><td>minor shoulder pain</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A002</td><td>14</td><td>basketball</td><td>Small Forward</td><td>beginner</td><td>Increase speed</td><td>none</td><td>3</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A003</td><td>14</td><td>basketball</td><td>Shooting Guard</td><td>beginner</td><td>Improve ball handling</td><td>knee recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A004</td><td>14</td><td>basketball</td><td>Power Forward</td><td>advanced</td><td>Improve defense</td><td>none</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A005</td><td>16</td><td>basketball</td><td>Shooting Guard</td><td>advanced</td><td>Build strength</td><td>knee recovery</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A006</td><td>15</td><td>basketball</td><td>Center</td><td>beginner</td><td>Increase vertical jump</td><td>minor shoulder pain</td><td>5</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A007</td><td>13</td><td>basketball</td><td>Point Guard</td><td>beginner</td><td>Increase vertical jump</td><td>ankle recovery</td><td>5</td><td>Basketball, Cones, Resistance Bands, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A008</td><td>16</td><td>basketball</td><td>Point Guard</td><td>advanced</td><td>Build strength</td><td>knee recovery</td><td>4</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A009</td><td>13</td><td>basketball</td><td>Small Forward</td><td>intermediate</td><td>Improve defense</td><td>minor shoulder pain</td><td>5</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A010</td><td>16</td><td>basketball</td><td>Shooting Guard</td><td>intermediate</td><td>Improve conditioning</td><td>none</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A011</td><td>17</td><td>basketball</td><td>Center</td><td>advanced</td><td>Improve agility</td><td>none</td><td>3</td><td>Basketball, Resistance Bands</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A012</td><td>13</td><td>basketball</td><td>Small Forward</td><td>beginner</td><td>Improve ball handling</td><td>ankle recovery</td><td>2</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A013</td><td>17</td><td>basketball</td><td>Small Forward</td><td>beginner</td><td>Improve conditioning</td><td>ankle recovery</td><td>6</td><td>Basketball</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A014</td><td>13</td><td>basketball</td><td>Shooting Guard</td><td>intermediate</td><td>Increase speed</td><td>none</td><td>6</td><td>Basketball, Cones, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A015</td><td>16</td><td>basketball</td><td>Point Guard</td><td>beginner</td><td>Improve defense</td><td>none</td><td>4</td><td>Basketball, Gym Access</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A016</td><td>15</td><td>basketball</td><td>Point Guard</td><td>beginner</td><td>Increase vertical jump</td><td>none</td><td>6</td><td>Basketball, Cones</td><td>Parent/Coach Oversight Required</td></tr><tr><td>A017</td><td>13</td><td>basketball</td><td>Center</td><td>beginner</td><td>Increase speed</td><td>none</td><td>2</td><td>Basketball, Cones, Gym Access</td><td>Parent/Coach Oversight Required< ...

# %%
#silver NBA Stats -- 

nba = spark.table("main.default.bronze_nba_stats")

silver_nba = (
    nba
    .dropDuplicates()
    .select(
        col("Year").cast("int").alias("season_year"),
        col("Player").alias("player_name"),
        col("Pos").alias("position"),
        col("Age").cast("int").alias("age"),
        col("G").cast("int").alias("games"),
        col("MP").cast("double").alias("minutes_played"),
        col("PTS").cast("double").alias("points"),
        col("AST").cast("double").alias("assists"),
        col("TRB").cast("double").alias("rebounds"),
        col("STL").cast("double").alias("steals"),
        col("BLK").cast("double").alias("blocks")
    )
    .filter(col("player_name").isNotNull())
)

silver_nba.write.mode("overwrite").saveAsTable(
    "main.default.silver_nba_stats"
)

display(silver_nba.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>season_year</th><th>player_name</th><th>position</th><th>age</th><th>games</th><th>minutes_played</th><th>points</th><th>assists</th><th>rebounds</th><th>steals</th><th>blocks</th></tr></thead><tbody><tr><td>1950</td><td>Curly Armstrong</td><td>G-F</td><td>31</td><td>63</td><td>null</td><td>458.0</td><td>176.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1950</td><td>Cliff Barker</td><td>SG</td><td>29</td><td>49</td><td>null</td><td>279.0</td><td>109.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1950</td><td>Leo Barnhorst</td><td>SF</td><td>25</td><td>67</td><td>null</td><td>438.0</td><td>140.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1950</td><td>Ed Bartels</td><td>F</td><td>24</td><td>15</td><td>null</td><td>63.0</td><td>20.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1950</td><td>Ed Bartels</td><td>F</td><td>24</td><td>13</td><td>null</td><td>59.0</td><td>20.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1950</td><td>Ed Bartels</td><td>F</td><td>24</td><td>2</td><td>null</td><td>4.0</td><td>0.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1950</td><td>Ralph Beard</td><td>G</td><td>22</td><td>60</td><td>null</td><td>895.0</td><td>233.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1950</td><td>Gene Berce</td><td>G-F</td><td>23</td><td>3</td><td>null</td><td>10.0</td><td>2.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1950</td><td>Charlie Black</td><td>F-C</td><td>28</td><td>65</td><td>null</td><td>661.0</td><td>163.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1950</td><td>Charlie Black</td><td>F-C</td><td>28</td><td>36</td><td>null</td><td>382.0</td><td>75.0</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
#silver GYM Exercises 
gym = spark.table("main.default.bronze_gym_exercises")

display(gym.limit(5))
print(gym.columns)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Title</th><th>Desc</th><th>Type</th><th>BodyPart</th><th>Equipment</th><th>Level</th><th>Rating</th><th>RatingDesc</th></tr></thead><tbody><tr><td>0</td><td>Partner plank band row</td><td>The partner plank band row is an abdominal exercise where two partners perform single-arm planks while pulling on the opposite ends of an exercise band. This technique can be done for time or reps in any ab-focused workout.</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>Intermediate</td><td>0.0</td><td>null</td></tr><tr><td>1</td><td>Banded crunch isometric hold</td><td>"The banded crunch isometric hold is an exercise targeting the abdominal muscles, particularly the rectus abdominis or ""six-pack"" muscles. The band adds resistance and continuous tension to this popular exercise."</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>Intermediate</td><td>null</td><td>null</td></tr><tr><td>2</td><td>FYR Banded Plank Jack</td><td>The banded plank jack is a variation on the plank that involves moving the legs in and out for repetitions. Having a band around the thighs forces the lower body to work harder, particularly the hips and glutes. The plank jack is commonly performed as part of a bodyweight circuit, or as part of a dynamic warm-up.</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>Intermediate</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Banded crunch</td><td>"The banded crunch is an exercise targeting the abdominal muscles, particularly the rectus abdominis or ""six-pack"" muscles. The band adds resistance and continuous tension to this popular exercise."</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>Intermediate</td><td>null</td><td>null</td></tr><tr><td>4</td><td>Crunch</td><td>"The crunch is a popular core exercise targeting the rectus abdominis, or ""six-pack"" muscles</td><td> as well as the obliques. It has been the centerpiece of many ab-focused workouts</td><td> due to both its simplicity and the intense burn and mind-muscle connection it produces. It can be performed for time or reps as part of the ab-focused portion of any workout."</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>Intermediate</td></tr></tbody></table></div>
# ['_c0', 'Title', 'Desc', 'Type', 'BodyPart', 'Equipment', 'Level', 'Rating', 'RatingDesc']

# %%
from pyspark.sql.functions import coalesce, lit

silver_gym = (
    gym
    .dropDuplicates()
    .select(
        col("Title").alias("exercise_name"),
        col("Desc").alias("description"),
        col("Type").alias("exercise_type"),
        col("BodyPart").alias("body_part"),
        col("Equipment").alias("equipment"),
        col("Level").alias("difficulty_level")
    )
    .withColumn("exercise_name", trim(col("exercise_name")))
    .withColumn("description", coalesce(col("description"), lit("No description available")))
    .withColumn("difficulty_level", lower(trim(col("difficulty_level"))))
    .filter(col("exercise_name").isNotNull())
)

silver_gym.write.mode("overwrite").saveAsTable(
    "main.default.silver_gym_exercises"
)

display(silver_gym.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>exercise_name</th><th>description</th><th>exercise_type</th><th>body_part</th><th>equipment</th><th>difficulty_level</th></tr></thead><tbody><tr><td>Partner plank band row</td><td>The partner plank band row is an abdominal exercise where two partners perform single-arm planks while pulling on the opposite ends of an exercise band. This technique can be done for time or reps in any ab-focused workout.</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>intermediate</td></tr><tr><td>Banded crunch isometric hold</td><td>"The banded crunch isometric hold is an exercise targeting the abdominal muscles, particularly the rectus abdominis or ""six-pack"" muscles. The band adds resistance and continuous tension to this popular exercise."</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>intermediate</td></tr><tr><td>FYR Banded Plank Jack</td><td>The banded plank jack is a variation on the plank that involves moving the legs in and out for repetitions. Having a band around the thighs forces the lower body to work harder, particularly the hips and glutes. The plank jack is commonly performed as part of a bodyweight circuit, or as part of a dynamic warm-up.</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>intermediate</td></tr><tr><td>Banded crunch</td><td>"The banded crunch is an exercise targeting the abdominal muscles, particularly the rectus abdominis or ""six-pack"" muscles. The band adds resistance and continuous tension to this popular exercise."</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>intermediate</td></tr><tr><td>Crunch</td><td>"The crunch is a popular core exercise targeting the rectus abdominis, or ""six-pack"" muscles</td><td> as well as the obliques. It has been the centerpiece of many ab-focused workouts</td><td> due to both its simplicity and the intense burn and mind-muscle connection it produces. It can be performed for time or reps as part of the ab-focused portion of any workout."</td><td>Strength</td><td>abdominals</td></tr><tr><td>Decline band press sit-up</td><td>"The decline band press sit-up is a weighted core exercise that works the rectus abdominis or ""six pack"" muscles</td><td> as well as the deep core muscles. It also taxes the muscles of the shoulders and upper back. Sit-up variations with added resistance are usually performed for moderate to high reps</td><td> such as 8-12 reps per set or more</td><td> as part of the core-focused portion of a workout."</td><td>strength</td></tr><tr><td>FYR2 Banded Frog Pump</td><td>No description available</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>intermediate</td></tr><tr><td>Band low-to-high twist</td><td>The band low-to-high twist is a core exercise targeting the upper abdominals and the obliques. Take care to perform it with control, as rapid, uncontrolled twisting can injure the spine. It is usually performed for moderate to high reps, at least 8-15 per side, as part of the core-focused portion of a workout.</td><td>Strength</td><td>Abdominals</td><td>Bands</td><td>intermediate</td></tr><tr><td>Barbell roll-out</td><td>The barbell roll-out is an abdominal exercise that utilizes a barbell in the place of an ab roller. It is best performed with a barbell that has rotating collars, and is considered more difficult than other ab roller variations. Many lifters may not be able to perform a single rep at first, but once they can perform these for reps, they'll be rewarded with a seriously strong core.</td><td>Strength</td><td>Abdominals</td><td>Barbell</td><td>intermediate</td></tr><tr><td>Barbell Ab Rollout - On Knees</td><td>The barbell roll-out is an abdominal exercise that utilizes a barbell in the place of an ab roller. It is best performed with a barbell that has rotating collars, and is considered more difficult than other ab roller variations. Many lifters may not be able to perform a single r ...

# %%
#Silver Food Nutrients 
food_nutrients = spark.table("main.default.bronze_food_nutrients")

display(food_nutrients.limit(5))
print(food_nutrients.columns)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>food_nutrient_id</th><th>adjusted_amount</th><th>lab_method_id</th><th>nutrient_name</th></tr></thead><tbody><tr><td>2201844</td><td>1.98</td><td>1004</td><td>Ash</td></tr><tr><td>2201845</td><td>1.28</td><td>1001</td><td>Nitrogen by Dumas</td></tr><tr><td>2201846</td><td>19.0</td><td>1053</td><td>Fat</td></tr><tr><td>2201847</td><td>56.3</td><td>1007</td><td>Moisture</td></tr><tr><td>2201848</td><td>46.2</td><td>1009</td><td>Calcium</td></tr></tbody></table></div>
# ['food_nutrient_id', 'adjusted_amount', 'lab_method_id', 'nutrient_name']

# %%
silver_food_nutrients = (
    food_nutrients
    .dropDuplicates()
)

silver_food_nutrients.write.mode("overwrite").saveAsTable(
    "main.default.silver_food_nutrients"
)

display(silver_food_nutrients.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>food_nutrient_id</th><th>adjusted_amount</th><th>lab_method_id</th><th>nutrient_name</th></tr></thead><tbody><tr><td>2201844</td><td>1.98</td><td>1004</td><td>Ash</td></tr><tr><td>2201845</td><td>1.28</td><td>1001</td><td>Nitrogen by Dumas</td></tr><tr><td>2201846</td><td>19.0</td><td>1053</td><td>Fat</td></tr><tr><td>2201847</td><td>56.3</td><td>1007</td><td>Moisture</td></tr><tr><td>2201848</td><td>46.2</td><td>1009</td><td>Calcium</td></tr><tr><td>2201849</td><td>2.33</td><td>1009</td><td>Iron</td></tr><tr><td>2201850</td><td>75.9</td><td>1009</td><td>Magnesium</td></tr><tr><td>2201851</td><td>1.21</td><td>1009</td><td>Manganese</td></tr><tr><td>2201852</td><td>188.0</td><td>1009</td><td>Phosphorus</td></tr><tr><td>2201853</td><td>326.0</td><td>1009</td><td>Potassium</td></tr></tbody></table></div>

# %%
#Silver Food Portions 

food_portions = spark.table("main.default.bronze_food_portions")

silver_food_portions = (
    food_portions
    .dropDuplicates()
)

silver_food_portions.write.mode("overwrite").saveAsTable(
    "main.default.silver_food_portions"
)

display(silver_food_portions.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>fdc_id</th><th>seq_num</th><th>amount</th><th>measure_unit_id</th><th>portion_description</th><th>modifier</th><th>gram_weight</th><th>data_points</th><th>footnote</th><th>min_year_acquired</th></tr></thead><tbody><tr><td>118702</td><td>319875</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>35.8</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118703</td><td>319880</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>36.2</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118704</td><td>319881</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>33.4</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118705</td><td>319886</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>33.2</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118706</td><td>319889</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>34.6</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118707</td><td>319895</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>34.8</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118708</td><td>319897</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>31.4</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118709</td><td>319902</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>32.0</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118710</td><td>319904</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>32.2</td><td>1</td><td>null</td><td>null</td></tr><tr><td>118711</td><td>319922</td><td>null</td><td>2.0</td><td>1001</td><td>null</td><td>null</td><td>33.6</td><td>1</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
#verifying the Silver tables -- 
spark.sql("SHOW TABLES IN main.default").show(truncate=False)
# Out:
# +--------+-------------------------+-----------+
# |database|tableName                |isTemporary|
# +--------+-------------------------+-----------+
# |default |assignment_file          |false      |
# |default |bronze_athlete_profiles  |false      |
# |default |bronze_food_categories   |false      |
# |default |bronze_food_nutrients    |false      |
# |default |bronze_food_portions     |false      |
# |default |bronze_food_sample       |false      |
# |default |bronze_gym_exercises     |false      |
# |default |bronze_nba_stats         |false      |
# |default |bronze_player_data       |false      |
# |default |bronze_players           |false      |
# |default |silver_athlete_profiles  |false      |
# |default |silver_food_nutrients    |false      |
# |default |silver_food_portions     |false      |
# |default |silver_gym_exercises     |false      |
# |default |silver_nba_stats         |false      |
# |default |ultrafeedback_embeddings |false      |
# |default |ultrafeedback_expert_eval|false      |
# +--------+-------------------------+-----------+
